# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r"check.csv")
data.shape
# Out:
# (17635, 29)

# %%
data.head(60)
# Out:
#    iso_code     location        date  total_cases  new_cases  total_deaths  \
# 0       ABW        Aruba  2020-03-13            2          2             0
# 1       ABW        Aruba  2020-03-20            4          2             0
# 2       ABW        Aruba  2020-03-24           12          8             0
# 3       ABW        Aruba  2020-03-25           17          5             0
# 4       ABW        Aruba  2020-03-26           19          2             0
# 5       ABW        Aruba  2020-03-27           28          9             0
# 6       ABW        Aruba  2020-03-28           28          0             0
# 7       ABW        Aruba  2020-03-29           28          0             0
# 8       ABW        Aruba  2020-03-30           50         22             0
# 9       ABW        Aruba  2020-04-01           55          5             0
# 10      ABW        Aruba  2020-04-02           55          0             0
# ...

# %%
temp = data.iloc[1577:1649,:]

# %%
temp.shape
temp.head(72)
# Out:
#      iso_code    location        date  total_cases  new_cases  total_deaths  \
# 1577      BGD  Bangladesh  2020-03-07            0          0             0
# 1578      BGD  Bangladesh  2020-03-08            0          0             0
# 1579      BGD  Bangladesh  2020-03-09            3          3             0
# 1580      BGD  Bangladesh  2020-03-10            0          0             0
# 1581      BGD  Bangladesh  2020-03-11            0          0             0
# ...       ...         ...         ...          ...        ...           ...
# 1644      BGD  Bangladesh  2020-05-13        16660        969           250
# 1645      BGD  Bangladesh  2020-05-14        17822       1162           269
# 1646      BGD  Bangladesh  2020-05-15        18863       1041           283
# 1647      BGD  Bangladesh  2020-05-16        20065       1202           298
# 1648      BGR    Bulgaria  2020-03-08            2          2             0
#
# ...

# %%
temp.to_csv(r"C:\Users\User\Downloads\BD_CVdata.csv", index = False)

# %%
temp.head(50)
# Out:
#      iso_code    location        date  total_cases  new_cases  total_deaths  \
# 1577      BGD  Bangladesh  2020-03-07            0          0             0
# 1578      BGD  Bangladesh  2020-03-08            0          0             0
# 1579      BGD  Bangladesh  2020-03-09            3          3             0
# 1580      BGD  Bangladesh  2020-03-10            0          0             0
# 1581      BGD  Bangladesh  2020-03-11            0          0             0
# 1582      BGD  Bangladesh  2020-03-12            0          0             0
# 1583      BGD  Bangladesh  2020-03-13            0          0             0
# 1584      BGD  Bangladesh  2020-03-14            0          0             0
# 1585      BGD  Bangladesh  2020-03-15            3          0             0
# 1586      BGD  Bangladesh  2020-03-16            0          0             0
# 1587      BGD  Bangladesh  2020-03-17            5          2             0
# ...

# %%
temp.to_csv(r"C:\Users\User\Downloads\BD_data.csv", index = False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-27-6b4b74f645fc> in <module>
# ----> 1 temp.to_csv(r"C:\Users\User\Downloads\BD_data.csv", index = False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     181                 self.mode,
#     182                 encoding=self.encoding,
# --> 183                 compression=self.compression,
#     184             )
#     185             close = True
#
# ...

# %%
data = pd.read_csv(r"C:\Users\User\Downloads\BD_data.csv")
data.shape
# Out:
# (67, 3)

# %%
data.head()
# Out:
#          date  total_cases  total_deaths
# 0  2020-03-07            0             0
# 1  2020-03-08            0             0
# 2  2020-03-09            3             0
# 3  2020-03-10            0             0
# 4  2020-03-11            0             0

# %%
header_names=['Date','Confirmed','Deaths']
data=pd.read_csv(r"C:\Users\User\Downloads\BD_data.csv",header=None,skiprows=1,names=header_names)

# %%
data.head()
# Out:
#          Date  Confirmed  Deaths
# 0  2020-03-07          0       0
# 1  2020-03-08          0       0
# 2  2020-03-09          3       0
# 3  2020-03-10          0       0
# 4  2020-03-11          0       0

# %%
data = pd.read_csv(r"C:\Users\User\Downloads\BD_data.csv")
data.shape
# Out:
# (67, 6)

# %%
data.head()
# Out:
#        Date  Confirmed  Recovered  Deaths  Number_of_daily_test  Total_Test
# 0  07-03-20        0.0        0.0     0.0                   3.0       108.0
# 1  08-03-20        0.0        0.0     0.0                   9.0       111.0
# 2  09-03-20        3.0        0.0     0.0                   7.0       120.0
# 3  10-03-20        0.0        0.0     0.0                  10.0       127.0
# 4  11-03-20        0.0        0.0     0.0                  10.0       137.0
